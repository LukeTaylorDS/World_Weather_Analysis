# %%
# Import initial libraries
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = list(zip(lats,lngs))

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key
print(weather_api_key)
# Out:
# 9d1230558ae5f9a9b1014a2cb4653bd6

# %%
# Assemble the OpenWeatherMap's API call
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=9d1230558ae5f9a9b1014a2cb4653bd6&units=imperial

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_desc
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | codrington
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hervey bay
# Processing Record 4 of Set 1 | sampit
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | fort payne
# Processing Record 7 of Set 1 | gwadar
# Processing Record 8 of Set 1 | lakes entrance
# Processing Record 9 of Set 1 | alta floresta
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | novyy urengoy
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | poum
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | uglovskoye
# Processing Record 20 of Set 1 | guantanamo
# Processing Record 21 of Set 1 | araouane
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | omboue
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | kathmandu
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | tarsus
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | danville
# Processing Record 31 of Set 1 | maldonado
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | isangel
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 1 | manaus
# Processing Record 45 of Set 1 | awassa
# Processing Record 46 of Set 1 | saint-georges
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | myskhako
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | hambantota
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | tari
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | kapuskasing
# Processing Record 8 of Set 2 | half moon bay
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | walvis bay
# Processing Record 13 of Set 2 | bara
# Processing Record 14 of Set 2 | evensk
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | northam
# Processing Record 17 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | sarahan
# Processing Record 19 of Set 2 | kudahuvadhoo
# Processing Record 20 of Set 2 | bambanglipuro
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | buchanan
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | beloha
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 2 | derzhavinsk
# Processing Record 29 of Set 2 | tabuk
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | biak
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | camocim
# Processing Record 37 of Set 2 | vostok
# Processing Record 38 of Set 2 | conceicao da barra
# Processing Record 39 of Set 2 | muros
# Processing Record 40 of Set 2 | general roca
# Processing Record 41 of Set 2 | byron bay
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | lubben
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | waycross
# Processing Record 46 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 47 of Set 2 | heinola
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | zhanaozen
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | that phanom
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | lucapa
# Processing Record 4 of Set 3 | rawson
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | teguldet
# Processing Record 9 of Set 3 | ambatofinandrahana
# Processing Record 10 of Set 3 | andapa
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | beisfjord
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | vanavara
# Processing Record 18 of Set 3 | keighley
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | caernarfon
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | nizhniy tsasuchey
# Processing Record 23 of Set 3 | beitbridge
# Processing Record 24 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | vanimo
# Processing Record 27 of Set 3 | luwingu
# Processing Record 28 of Set 3 | angoche
# Processing Record 29 of Set 3 | kloulklubed
# Processing Record 30 of Set 3 | turukhansk
# Processing Record 31 of Set 3 | sopur
# Processing Record 32 of Set 3 | champaign
# Processing Record 33 of Set 3 | labuhan
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | deputatskiy
# Processing Record 36 of Set 3 | marsa matruh
# Processing Record 37 of Set 3 | plettenberg bay
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | kutum
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | sokoni
# Processing Record 44 of Set 3 | kota kinabalu
# Processing Record 45 of Set 3 | wanaka
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | guerrero negro
# Processing Record 48 of Set 3 | minab
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | kirakira
# Processing Record 1 of Set 4 | saint-augustin
# Processing Record 2 of Set 4 | wajima
# Processing Record 3 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 4 | dafeng
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | the valley
# Processing Record 11 of Set 4 | pitimbu
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | mayor pablo lagerenza
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | husavik
# Processing Record 18 of Set 4 | boshnyakovo
# Processing Record 19 of Set 4 | palang
# Processing Record 20 of Set 4 | puerto carreno
# Processing Record 21 of Set 4 | ous
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | lasa
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | thiers
# Processing Record 26 of Set 4 | kensington
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | saba
# Processing Record 31 of Set 4 | vila
# Processing Record 32 of Set 4 | banda aceh
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | gagino
# Processing Record 35 of Set 4 | beyneu
# Processing Record 36 of Set 4 | ossora
# Processing Record 37 of Set 4 | itacare
# Processing Record 38 of Set 4 | salalah
# Processing Record 39 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 4 | papara
# Processing Record 41 of Set 4 | tutoia
# Processing Record 42 of Set 4 | aksarka
# Processing Record 43 of Set 4 | katobu
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | neiafu
# Processing Record 46 of Set 4 | telimele
# Processing Record 47 of Set 4 | stromness
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | tshikapa
# Processing Record 50 of Set 4 | coihaique
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | sale
# Processing Record 3 of Set 5 | krasnoselkup
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | hakodate
# Processing Record 6 of Set 5 | qui nhon
# Processing Record 7 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 5 | muisne
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | fukue
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | raahe
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 5 | tomatlan
# Processing Record 16 of Set 5 | lavrentiya
# Processing Record 17 of Set 5 | cuauhtemoc
# Processing Record 18 of Set 5 | yellowknife
# Processing Record 19 of Set 5 | oktyabrskiy
# Processing Record 20 of Set 5 | udachnyy
# Processing Record 21 of Set 5 | stroitel
# Processing Record 22 of Set 5 | eura
# Processing Record 23 of Set 5 | darhan
# Processing Record 24 of Set 5 | zarautz
# Processing Record 25 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 5 | bodaybo
# Processing Record 27 of Set 5 | beidao
# Processing Record 28 of Set 5 | nancha
# Processing Record 29 of Set 5 | maku
# Processing Record 30 of Set 5 | yar-sale
# Processing Record 31 of Set 5 | talcahuano
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | bakchar
# Processing Record 35 of Set 5 | mumford
# Processing Record 36 of Set 5 | doha
# Processing Record 37 of Set 5 | sola
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | roros
# Processing Record 40 of Set 5 | sulangan
# Processing Record 41 of Set 5 | san vicente
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | tecpan
# Processing Record 44 of Set 5 | kununurra
# Processing Record 45 of Set 5 | namatanai
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | suzu
# City not found. Skipping...
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | vestmanna
# Processing Record 1 of Set 6 | balaipungut
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | tucuma
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | qasigiannguit
# Processing Record 6 of Set 6 | kunzelsau
# Processing Record 7 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 8 of Set 6 | hoi an
# Processing Record 9 of Set 6 | kuryk
# Processing Record 10 of Set 6 | port blair
# Processing Record 11 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 6 | terrak
# Processing Record 13 of Set 6 | acajutla
# Processing Record 14 of Set 6 | sibolga
# Processing Record 15 of Set 6 | bone
# Processing Record 16 of Set 6 | espanola
# Processing Record 17 of Set 6 | ketchikan
# Processing Record 18 of Set 6 | pekin
# Processing Record 19 of Set 6 | hobyo
# Processing Record 20 of Set 6 | vestmannaeyjar
# Processing Record 21 of Set 6 | malakal
# Processing Record 22 of Set 6 | concepcion del uruguay
# Processing Record 23 of Set 6 | nelson bay
# Processing Record 24 of Set 6 | seymchan
# Processing Record 25 of Set 6 | tekkali
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | nadym
# Processing Record 28 of Set 6 | tsiroanomandidy
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | dudinka
# Processing Record 31 of Set 6 | tuktoyaktuk
# Processing Record 32 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 6 | kimbe
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | elizabeth city
# Processing Record 36 of Set 6 | sabya
# Processing Record 37 of Set 6 | hirara
# Processing Record 38 of Set 6 | ambon
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | veselynove
# Processing Record 41 of Set 6 | bend
# Processing Record 42 of Set 6 | isla mujeres
# Processing Record 43 of Set 6 | uren
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | sumbe
# Processing Record 47 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 6 | kundiawa
# Processing Record 49 of Set 6 | baracoa
# Processing Record 50 of Set 6 | cutro
# Processing Record 1 of Set 7 | clevelandia
# Processing Record 2 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 7 | kabare
# Processing Record 4 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 5 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 7 | buraydah
# Processing Record 7 of Set 7 | morant bay
# Processing Record 8 of Set 7 | tchollire
# Processing Record 9 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 7 | wilmington
# Processing Record 11 of Set 7 | ponta do sol
# Processing Record 12 of Set 7 | mata grande
# Processing Record 13 of Set 7 | ust-nera
# Processing Record 14 of Set 7 | along
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | sept-iles
# Processing Record 17 of Set 7 | bulgan
# Processing Record 18 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 7 | opuwo
# Processing Record 20 of Set 7 | taoudenni
# Processing Record 21 of Set 7 | kaiu
# Processing Record 22 of Set 7 | yumen
# Processing Record 23 of Set 7 | forest grove
# Processing Record 24 of Set 7 | koslan
# Processing Record 25 of Set 7 | urengoy
# Processing Record 26 of Set 7 | mankono
# Processing Record 27 of Set 7 | saint john
# Processing Record 28 of Set 7 | ojinaga
# Processing Record 29 of Set 7 | kindu
# Processing Record 30 of Set 7 | kavaratti
# Processing Record 31 of Set 7 | kaniama
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | bayevo
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | ivaipora
# Processing Record 36 of Set 7 | dolinsk
# Processing Record 37 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | hailun
# Processing Record 40 of Set 7 | north bend
# Processing Record 41 of Set 7 | matamoros
# Processing Record 42 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 7 | santa cruz
# Processing Record 44 of Set 7 | lazaro cardenas
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | abu kamal
# Processing Record 47 of Set 7 | baykit
# Processing Record 48 of Set 7 | namibe
# Processing Record 49 of Set 7 | tottori
# Processing Record 50 of Set 7 | abadan
# Processing Record 1 of Set 8 | chimbote
# Processing Record 2 of Set 8 | alice
# Processing Record 3 of Set 8 | limbazi
# Processing Record 4 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | melfort
# Processing Record 7 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 8 | tenango
# Processing Record 9 of Set 8 | bethel
# Processing Record 10 of Set 8 | pangnirtung
# Processing Record 11 of Set 8 | bonfim
# Processing Record 12 of Set 8 | margate
# Processing Record 13 of Set 8 | rusape
# Processing Record 14 of Set 8 | independence
# Processing Record 15 of Set 8 | tazovskiy
# Processing Record 16 of Set 8 | ruston
# Processing Record 17 of Set 8 | san cristobal
# Processing Record 18 of Set 8 | mongo
# Processing Record 19 of Set 8 | santa maria
# Processing Record 20 of Set 8 | hede
# Processing Record 21 of Set 8 | kotdwara
# Processing Record 22 of Set 8 | pailon
# Processing Record 23 of Set 8 | tarpa
# Processing Record 24 of Set 8 | kapiri mposhi
# Processing Record 25 of Set 8 | huamachuco
# Processing Record 26 of Set 8 | los llanos de aridane
# Processing Record 27 of Set 8 | berlevag
# Processing Record 28 of Set 8 | kasama
# Processing Record 29 of Set 8 | bezopasnoye
# Processing Record 30 of Set 8 | ramhormoz
# Processing Record 31 of Set 8 | nanga eboko
# Processing Record 32 of Set 8 | geraldton
# Processing Record 33 of Set 8 | esperance
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | vagur
# Processing Record 36 of Set 8 | sisimiut
# Processing Record 37 of Set 8 | roald
# Processing Record 38 of Set 8 | galveston
# Processing Record 39 of Set 8 | busayra
# Processing Record 40 of Set 8 | klyuchi
# Processing Record 41 of Set 8 | benjamin hill
# Processing Record 42 of Set 8 | charleston
# Processing Record 43 of Set 8 | kahului
# Processing Record 44 of Set 8 | eureka
# Processing Record 45 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 8 | chhindwara
# Processing Record 48 of Set 8 | souillac
# Processing Record 49 of Set 8 | issia
# Processing Record 50 of Set 8 | quatre cocos
# Processing Record 1 of Set 9 | noumea
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | nanae
# Processing Record 4 of Set 9 | tura
# Processing Record 5 of Set 9 | killybegs
# Processing Record 6 of Set 9 | north myrtle beach
# Processing Record 7 of Set 9 | tiksi
# Processing Record 8 of Set 9 | riohacha
# Processing Record 9 of Set 9 | road town
# Processing Record 10 of Set 9 | vetluga
# Processing Record 11 of Set 9 | plyussa
# Processing Record 12 of Set 9 | fairbanks
# Processing Record 13 of Set 9 | leningradskiy
# Processing Record 14 of Set 9 | cartama
# Processing Record 15 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 16 of Set 9 | saskatoon
# Processing Record 17 of Set 9 | aasiaat
# Processing Record 18 of Set 9 | necochea
# Processing Record 19 of Set 9 | merritt
# Processing Record 20 of Set 9 | skjervoy
# Processing Record 21 of Set 9 | hay river
# Processing Record 22 of Set 9 | pisco
# Processing Record 23 of Set 9 | nanortalik
# Processing Record 24 of Set 9 | jacqueville
# Processing Record 25 of Set 9 | balashov
# Processing Record 26 of Set 9 | alibunan
# Processing Record 27 of Set 9 | lima
# Processing Record 28 of Set 9 | gunjur
# Processing Record 29 of Set 9 | port-gentil
# Processing Record 30 of Set 9 | chaplynka
# Processing Record 31 of Set 9 | yerbogachen
# Processing Record 32 of Set 9 | zhoucheng
# Processing Record 33 of Set 9 | galway
# Processing Record 34 of Set 9 | chabahar
# Processing Record 35 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 9 | okhotsk
# Processing Record 37 of Set 9 | russell
# Processing Record 38 of Set 9 | flin flon
# Processing Record 39 of Set 9 | vysokogornyy
# Processing Record 40 of Set 9 | mandera
# Processing Record 41 of Set 9 | mattru
# Processing Record 42 of Set 9 | betare oya
# Processing Record 43 of Set 9 | ahipara
# Processing Record 44 of Set 9 | mga
# Processing Record 45 of Set 9 | antalaha
# Processing Record 46 of Set 9 | marsabit
# Processing Record 47 of Set 9 | balkhash
# Processing Record 48 of Set 9 | marsh harbour
# Processing Record 49 of Set 9 | atotonilco el grande
# Processing Record 50 of Set 9 | zhuhai
# Processing Record 1 of Set 10 | wabash
# Processing Record 2 of Set 10 | sellye
# Processing Record 3 of Set 10 | te anau
# Processing Record 4 of Set 10 | letka
# Processing Record 5 of Set 10 | nemuro
# Processing Record 6 of Set 10 | pochutla
# Processing Record 7 of Set 10 | san juan
# Processing Record 8 of Set 10 | faanui
# Processing Record 9 of Set 10 | burdur
# Processing Record 10 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 11 of Set 10 | sioux lookout
# Processing Record 12 of Set 10 | hualmay
# Processing Record 13 of Set 10 | maraa
# Processing Record 14 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 15 of Set 10 | ilebo
# Processing Record 16 of Set 10 | rorvik
# Processing Record 17 of Set 10 | joshimath
# Processing Record 18 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 10 | kovdor
# Processing Record 20 of Set 10 | batemans bay
# Processing Record 21 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 10 | aquiles serdan
# Processing Record 24 of Set 10 | beian
# Processing Record 25 of Set 10 | ternate
# Processing Record 26 of Set 10 | preobrazheniye
# Processing Record 27 of Set 10 | enshi
# Processing Record 28 of Set 10 | westport
# Processing Record 29 of Set 10 | camalu
# Processing Record 30 of Set 10 | ust-ishim
# Processing Record 31 of Set 10 | yangambi
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | gohad
# Processing Record 36 of Set 10 | qostanay
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | ulaangom
# Processing Record 39 of Set 10 | zhigansk
# Processing Record 40 of Set 10 | las palmas
# Processing Record 41 of Set 10 | weiser
# Processing Record 42 of Set 10 | terrace bay
# Processing Record 43 of Set 10 | fort-shevchenko
# Processing Record 44 of Set 10 | juneau
# Processing Record 45 of Set 10 | vardo
# Processing Record 46 of Set 10 | ostrovnoy
# Processing Record 47 of Set 10 | mugumu
# Processing Record 48 of Set 10 | ankang
# Processing Record 49 of Set 10 | itaueira
# Processing Record 50 of Set 10 | inirida
# Processing Record 1 of Set 11 | cherepovets
# Processing Record 2 of Set 11 | tuatapere
# Processing Record 3 of Set 11 | bilma
# Processing Record 4 of Set 11 | ishigaki
# Processing Record 5 of Set 11 | ovre ardal
# Processing Record 6 of Set 11 | christchurch
# Processing Record 7 of Set 11 | natal
# Processing Record 8 of Set 11 | bosaso
# Processing Record 9 of Set 11 | nabire
# Processing Record 10 of Set 11 | qaqortoq
# Processing Record 11 of Set 11 | vangaindrano
# Processing Record 12 of Set 11 | slave lake
# Processing Record 13 of Set 11 | haapiti
# Processing Record 14 of Set 11 | tugulym
# Processing Record 15 of Set 11 | bowen
# Processing Record 16 of Set 11 | sigli
# Processing Record 17 of Set 11 | port lincoln
# Processing Record 18 of Set 11 | kenai
# Processing Record 19 of Set 11 | klaksvik
# Processing Record 20 of Set 11 | brae
# Processing Record 21 of Set 11 | trollhattan
# Processing Record 22 of Set 11 | martapura
# Processing Record 23 of Set 11 | aktau
# Processing Record 24 of Set 11 | blackwater
# Processing Record 25 of Set 11 | thinadhoo
# Processing Record 26 of Set 11 | fortuna
# Processing Record 27 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 11 | atambua
# Processing Record 29 of Set 11 | meulaboh
# Processing Record 30 of Set 11 | pimenta bueno
# Processing Record 31 of Set 11 | chimala
# Processing Record 32 of Set 11 | chernyshevskiy
# Processing Record 33 of Set 11 | lata
# Processing Record 34 of Set 11 | charlottetown
# Processing Record 35 of Set 11 | brigantine
# Processing Record 36 of Set 11 | muroto
# Processing Record 37 of Set 11 | shaoyang
# Processing Record 38 of Set 11 | gayeri
# Processing Record 39 of Set 11 | abha
# Processing Record 40 of Set 11 | nsanje
# Processing Record 41 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 11 | myitkyina
# Processing Record 45 of Set 11 | asfi
# Processing Record 46 of Set 11 | lorengau
# Processing Record 47 of Set 11 | kiruna
# Processing Record 48 of Set 11 | shinpokh
# Processing Record 49 of Set 11 | hebi
# Processing Record 50 of Set 11 | kushima
# Processing Record 1 of Set 12 | olds
# Processing Record 2 of Set 12 | arlit
# Processing Record 3 of Set 12 | safita
# Processing Record 4 of Set 12 | macaiba
# Processing Record 5 of Set 12 | porto novo
# Processing Record 6 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 12 | nipawin
# Processing Record 8 of Set 12 | porto santo
# Processing Record 9 of Set 12 | inhambane
# Processing Record 10 of Set 12 | puri
# Processing Record 11 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 12 | lahat
# Processing Record 13 of Set 12 | ambanja
# Processing Record 14 of Set 12 | taicheng
# Processing Record 15 of Set 12 | umm lajj
# Processing Record 16 of Set 12 | sobolevo
# Processing Record 17 of Set 12 | karratha
# Processing Record 18 of Set 12 | stockelsdorf
# Processing Record 19 of Set 12 | mosquera
# Processing Record 20 of Set 12 | sakakah
# Processing Record 21 of Set 12 | plainview
# Processing Record 22 of Set 12 | smithers
# Processing Record 23 of Set 12 | takoradi
# Processing Record 24 of Set 12 | lyubim
# Processing Record 25 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 12 | dawei
# Processing Record 27 of Set 12 | matara
# Processing Record 28 of Set 12 | bonavista
# Processing Record 29 of Set 12 | murchison
# Processing Record 30 of Set 12 | berdigestyakh
# Processing Record 31 of Set 12 | port hedland
# Processing Record 32 of Set 12 | goma
# Processing Record 33 of Set 12 | mariental
# Processing Record 34 of Set 12 | belyy yar
# Processing Record 35 of Set 12 | jalalabad
# Processing Record 36 of Set 12 | samarai
# Processing Record 37 of Set 12 | tunduma
# Processing Record 38 of Set 12 | tahe
# Processing Record 39 of Set 12 | sabha
# Processing Record 40 of Set 12 | tautira
# Processing Record 41 of Set 12 | rio grande
# Processing Record 42 of Set 12 | iquitos
# Processing Record 43 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 12 | ferrol
# Processing Record 45 of Set 12 | auki
# Processing Record 46 of Set 12 | grottaglie
# Processing Record 47 of Set 12 | gilgit
# Processing Record 48 of Set 12 | zhifang
# Processing Record 49 of Set 12 | muli
# Processing Record 50 of Set 12 | odawara
# Processing Record 1 of Set 13 | jalu
# Processing Record 2 of Set 13 | dongsheng
# Processing Record 3 of Set 13 | wattegama
# Processing Record 4 of Set 13 | grindavik
# Processing Record 5 of Set 13 | mehamn
# Processing Record 6 of Set 13 | aksu
# Processing Record 7 of Set 13 | abalak
# Processing Record 8 of Set 13 | rio cuarto
# Processing Record 9 of Set 13 | talipparamba
# Processing Record 10 of Set 13 | alindao
# Processing Record 11 of Set 13 | halifax
# Processing Record 12 of Set 13 | burgeo
# Processing Record 13 of Set 13 | vredendal
# Processing Record 14 of Set 13 | havre-saint-pierre
# Processing Record 15 of Set 13 | coahuayana
# Processing Record 16 of Set 13 | bari
# Processing Record 17 of Set 13 | cheremnoye
# Processing Record 18 of Set 13 | wanning
# Processing Record 19 of Set 13 | shache
# Processing Record 20 of Set 13 | mosjoen
# Processing Record 21 of Set 13 | suntar
# Processing Record 22 of Set 13 | jose de freitas
# Processing Record 23 of Set 13 | buckeye
# Processing Record 24 of Set 13 | orsha
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | kurilsk
# Processing Record 27 of Set 13 | yeniseysk
# Processing Record 28 of Set 13 | chaykovskaya
# Processing Record 29 of Set 13 | anchorage
# Processing Record 30 of Set 13 | san jose
# Processing Record 31 of Set 13 | korla
# Processing Record 32 of Set 13 | loukhi
# Processing Record 33 of Set 13 | tkvarcheli
# City not found. Skipping...
# Processing Record 34 of Set 13 | arman
# Processing Record 35 of Set 13 | santa
# Processing Record 36 of Set 13 | ulladulla
# Processing Record 37 of Set 13 | skibbereen
# Processing Record 38 of Set 13 | eenhana
# Processing Record 39 of Set 13 | maarianhamina
# Processing Record 40 of Set 13 | tilichiki
# Processing Record 41 of Set 13 | yenagoa
# Processing Record 42 of Set 13 | namanga
# Processing Record 43 of Set 13 | mareeba
# Processing Record 44 of Set 13 | gushikawa
# Processing Record 45 of Set 13 | nisia floresta
# Processing Record 46 of Set 13 | kalmunai
# Processing Record 47 of Set 13 | olafsvik
# Processing Record 48 of Set 13 | kitimat
# Processing Record 49 of Set 13 | timbiqui
# Processing Record 50 of Set 13 | yuxia
# Processing Record 1 of Set 14 | iralaya
# Processing Record 2 of Set 14 | avera
# Processing Record 3 of Set 14 | ballina
# Processing Record 4 of Set 14 | huarmey
# Processing Record 5 of Set 14 | barcelos
# Processing Record 6 of Set 14 | sergeyevka
# Processing Record 7 of Set 14 | dawson creek
# Processing Record 8 of Set 14 | brainerd
# Processing Record 9 of Set 14 | whitianga
# Processing Record 10 of Set 14 | pasco
# Processing Record 11 of Set 14 | hamilton
# Processing Record 12 of Set 14 | vieques
# Processing Record 13 of Set 14 | merauke
# Processing Record 14 of Set 14 | mocuba
# Processing Record 15 of Set 14 | longonjo
# Processing Record 16 of Set 14 | balikpapan
# Processing Record 17 of Set 14 | dongfeng
# Processing Record 18 of Set 14 | lieksa
# Processing Record 19 of Set 14 | barabinsk
# Processing Record 20 of Set 14 | zachary
# Processing Record 21 of Set 14 | suluq
# Processing Record 22 of Set 14 | tiznit
# Processing Record 23 of Set 14 | zharkent
# Processing Record 24 of Set 14 | goderich
# Processing Record 25 of Set 14 | paamiut
# Processing Record 26 of Set 14 | banfora
# Processing Record 27 of Set 14 | kysyl-syr
# Processing Record 28 of Set 14 | anloga
# Processing Record 29 of Set 14 | osa
# Processing Record 30 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 14 | pergamino
# Processing Record 32 of Set 14 | palafrugell
# Processing Record 33 of Set 14 | carutapera
# Processing Record 34 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 14 | antsohihy
# Processing Record 36 of Set 14 | vysokaya gora
# Processing Record 37 of Set 14 | makakilo city
# Processing Record 38 of Set 14 | riyadh
# Processing Record 39 of Set 14 | cuenca
# Processing Record 40 of Set 14 | jiazi
# Processing Record 41 of Set 14 | fare
# Processing Record 42 of Set 14 | hofn
# Processing Record 43 of Set 14 | nieuw amsterdam
# Processing Record 44 of Set 14 | simoes
# Processing Record 45 of Set 14 | laguna
# Processing Record 46 of Set 14 | atbasar
# Processing Record 47 of Set 14 | zalantun
# Processing Record 48 of Set 14 | alice springs
# Processing Record 49 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 14 | ust-uda
# Processing Record 1 of Set 15 | muzquiz
# City not found. Skipping...
# Processing Record 2 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 15 | urumqi
# Processing Record 4 of Set 15 | casselman
# Processing Record 5 of Set 15 | belaya gora
# Processing Record 6 of Set 15 | tuyen quang
# Processing Record 7 of Set 15 | passo de camaragibe
# Processing Record 8 of Set 15 | san felipe
# Processing Record 9 of Set 15 | grand gaube
# Processing Record 10 of Set 15 | viedma
# Processing Record 11 of Set 15 | tandil
# Processing Record 12 of Set 15 | paragominas
# Processing Record 13 of Set 15 | koberice
# Processing Record 14 of Set 15 | beira
# Processing Record 15 of Set 15 | itarema
# Processing Record 16 of Set 15 | ginda
# Processing Record 17 of Set 15 | salinas
# Processing Record 18 of Set 15 | progreso
# Processing Record 19 of Set 15 | niltepec
# Processing Record 20 of Set 15 | amla
# Processing Record 21 of Set 15 | znamenskoye
# Processing Record 22 of Set 15 | yulara
# Processing Record 23 of Set 15 | toma
# Processing Record 24 of Set 15 | wana
# Processing Record 25 of Set 15 | ugoofaaru
# Processing Record 26 of Set 15 | rodrigues alves
# Processing Record 27 of Set 15 | pokrovskoye
# Processing Record 28 of Set 15 | santa isabel do rio negro
# Processing Record 29 of Set 15 | mokhotlong
# Processing Record 30 of Set 15 | shasta lake
# Processing Record 31 of Set 15 | quesnel
# Processing Record 32 of Set 15 | chilac
# City not found. Skipping...
# Processing Record 33 of Set 15 | alofi
# Processing Record 34 of Set 15 | jiwani
# Processing Record 35 of Set 15 | nishihara
# Processing Record 36 of Set 15 | zeya
# Processing Record 37 of Set 15 | pacocha
# Processing Record 38 of Set 15 | virginia beach
# Processing Record 39 of Set 15 | garowe
# Processing Record 40 of Set 15 | chapaevsk
# Processing Record 41 of Set 15 | matay
# Processing Record 42 of Set 15 | mountain home
# Processing Record 43 of Set 15 | niono
# Processing Record 44 of Set 15 | karla
# Processing Record 45 of Set 15 | mulege
# Processing Record 46 of Set 15 | tessalit
# Processing Record 47 of Set 15 | manokwari
# Processing Record 48 of Set 15 | waingapu
# Processing Record 49 of Set 15 | teahupoo
# Processing Record 50 of Set 15 | mormugao
# Processing Record 1 of Set 16 | tabarqah
# City not found. Skipping...
# Processing Record 2 of Set 16 | vila franca do campo
# Processing Record 3 of Set 16 | praya
# Processing Record 4 of Set 16 | saint-louis
# Processing Record 5 of Set 16 | verkhnevilyuysk
# Processing Record 6 of Set 16 | pandan
# Processing Record 7 of Set 16 | koungou
# Processing Record 8 of Set 16 | buala
# Processing Record 9 of Set 16 | pandamatenga
# Processing Record 10 of Set 16 | mount isa
# Processing Record 11 of Set 16 | bandarbeyla
# Processing Record 12 of Set 16 | dobsice
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Codrington      AU -38.2667  141.9667     56.26        79          48
# 1       Busselton      AU -33.6500  115.3333     54.18        81          56
# 2      Hervey Bay      AU -25.2986  152.8535     76.26        75          75
# 3          Sampit      ID  -2.5333  112.9500     72.10        98          96
# 4          Barrow      US  71.2906 -156.7887      2.86        85          75
# 5      Fort Payne      US  34.4442  -85.7197     68.61        45          40
# 6          Gwadar      PK  25.1216   62.3254     76.35        79           0
# 7  Lakes Entrance      AU -37.8811  147.9810     63.16        94         100
# 8   Alta Floresta      BR  -9.8756  -56.0861     77.04        92          98
# 9          Albany      US  42.6001  -73.9662     49.17        47          29
#
#    Wind Speed   Weather Description
# 0        8.48      scattered clouds
# 1       11.36         broken clouds
# 2        4.65         broken clouds
# 3        0.47       overcast clouds
# 4       14.99         broken clouds
# 5       13.80      scattered clouds
# 6       15.90            light rain
# 7        7.85            light rain
# 8        3.38  heavy intensity rain
# 9        5.99      scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Weather Description'],
#       dtype='object')

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %%
# Set the output file name
weather_df = pd.DataFrame(city_data)
weather_df.head()

# Export the city_data DataFrame into a CSV file
weather_df.to_csv('WeatherPy_Database.csv', index=False)
